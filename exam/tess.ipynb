# %% [markdown]
# # suyog khafdka

# %% [markdown]
# # c37278482

# %% [markdown]
# i ams ye ascugasdy ewhw defdkuewfaew fewf gewf fsefsfbh wygfwy

# %%
unique_strings = set() # Sets automatically handle uniqueness

print("Enter strings (Press Enter to finish):")
while True:
    user_input = input()
    if user_input == "":
        break
    unique_strings.add(user_input)

print(f"Number of unique strings entered: {len(unique_strings)}")
